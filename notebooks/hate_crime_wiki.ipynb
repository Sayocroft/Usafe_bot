# %%
# For text preprocessing
import nltk
import re
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer

# For sentiment analysis with TextBlob
from textblob import TextBlob

# For Bag of Words and TF-IDF
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer

# For Naive Bayes classification
from sklearn.naive_bayes import MultinomialNB
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, classification_report

# Optional - for VADER sentiment analysis
from nltk.sentiment.vader import SentimentIntensityAnalyzer

# Make sure to download any required NLTK datasets if you haven't already
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('vader_lexicon')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package punkt to /Users/sayo/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /Users/sayo/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/sayo/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# [nltk_data] Downloading package wordnet to /Users/sayo/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
# Load the text file located in the 'data' folder
try:
    with open('/Users/sayo/personal_projects/Usafe_bot/data/hate_crime.txt', 'r', encoding='utf-8') as file:
        text = file.read()
    print("Text loaded successfully!")
except FileNotFoundError:
    print("The file 'hate_crime.txt' was not found in the 'data' folder. Please check the path.")
except Exception as e:
    print("An error occurred:", e)
# Out:
# Text loaded successfully!

# %%
# Initialize the stop words and lemmatizer
stop_words = set(stopwords.words('english'))
lemmatizer = WordNetLemmatizer()

# Split sections by headings that follow the pattern '== Heading =='
sections = re.split(r'== (.*?) ==', text)

# Dictionary to store cleaned sections
processed_sections = {}

# Loop through sections, process each one by keeping heading and content pairs
for i in range(1, len(sections), 2):  # Start at 1 and increment by 2 to get heading/content pairs
    heading = sections[i].strip()  # Section heading
    content = sections[i + 1]  # Section content
    
    # Tokenize, remove stopwords, and apply lemmatization
    tokens = word_tokenize(content)
    cleaned_tokens = [
        lemmatizer.lemmatize(word.lower()) 
        for word in tokens 
        if word.isalpha() and word.lower() not in stop_words
    ]
    
    # Join cleaned tokens back into a single string for the section content
    processed_sections[heading] = ' '.join(cleaned_tokens)

# Display a sample of the processed sections
for heading, content in processed_sections.items():
    print(f"Heading: {heading}")
    print(f"Content: {content[:200]}...")  # Display the first 200 characters of each section
    print("\n---\n")
# Out:
# Heading: History
# Content: term hate crime came common usage united state often used retrospectively order describe event occurred prior era roman persecution christian nazi slaughter jew hate crime committed individual well go...
#
# ---
#
# Heading: Psychological effects
# Content: hate crime significant psychological consequence direct victim others group well moreover victim hate crime often experience sense victimization go beyond initial crime creating heightened sense vulne...
#
# ---
#
# Heading: Motivation
# Content: sociologist jack mcdevitt jack levin study motif hate crime found four motif reported accounted percent hate crime overall united state perpetrator engage hate crime excitement drama often greater pur...
#
# ---
#
# Heading: Risk management for hate-crime offenders
# Content: compared type offending relatively little research directed towards management offender however risk management offender important consideration forensic psychology public safety order decrease potent...
#
# ---
#
# Heading: Laws
# Content: hate crime law generally fall one several category law defining specific act distinct crime criminal law law creating distinct civil cause action hate crime law requiring administrative agency collect...
#
# ---
#
# Heading: Europe and Asia
# Content: ...
#
# ---
#
# Heading: Council of Europe
# Content: since additional protocol convention cybercrime signatory convention mostly member council europe committed punish crime racist xenophobic hate speech done internet...
#
# ---
#
# Heading: Andorra
# Content: discriminatory act constituting harassment infringement person dignity basis origin citizenship race religion gender penal code article court cited motivation delivering sentence explicit penalty enha...
#
# ---
#
# Heading: Armenia
# Content: armenia statute crime ethnic racial religious motif criminal code article...
#
# ---
#
# Heading: Austria
# Content: austria statute reason like repeating crime especially cruel using others helpless state playing leading role crime committing crime racist xenophobic especially reprehensible motivation penal code se...
#
# ---
#
# Heading: Azerbaijan
# Content: azerbaijan statute crime motivated racial national religious hatred criminal code article murder infliction serious bodily injury motivated racial religious national ethnic intolerance distinct crime ...
#
# ---
#
# Heading: Belarus
# Content: belarus statute crime motivated racial national religious hatred discord...
#
# ---
#
# Heading: Belgium
# Content: belgium act february aimed combating discrimination modifying act february establishes centre equal opportunity fight racism establishes crime involving discrimination basis gender supposed race color...
#
# ---
#
# Heading: Bosnia and Herzegovina
# Content: criminal code bosnia herzegovina enacted contains provision prohibiting discrimination public official ground inter alia race skin colour national ethnic background religion language prohibiting restr...
#
# ---
#
# Heading: Bulgaria
# Content: bulgarian criminal law prohibits certain crime motivated racism xenophobia report european commission racism intolerance found appear provision ever resulted conviction court bulgaria...
#
# ---
#
# Heading: Croatia
# Content: croatian penal code explicitly defines hate crime article crime committed hatred someone race skin color sex sexual orientation language religion political belief national social background asset birt...
#
# ---
#
# Heading: Czech Republic
# Content: czech legislation find constitutional basis principle equality contained charter fundamental right basic freedom trace two basic line protection incident one pass criminal law civil law current czech ...
#
# ---
#
# Heading: Denmark
# Content: although danish law include explicit hate crime provision section criminal code instructs court take account gravity offence offender motive meting penalty therefore attach importance racist motive cr...
#
# ---
#
# Heading: Estonia
# Content: section criminal code estonia june entered force september amendment supplement amended law december activity publicly incite hatred violence discrimination basis nationality race colour sex language ...
#
# ---
#
# Heading: Finland
# Content: finnish criminal code enacted january make committing crime person national racial ethnical equivalent group aggravating circumstance sentencing addition ethnic agitation finnish kiihotus kansanryhmää...
#
# ---
#
# Heading: France
# Content: france enacted hate crime law crime motivated bias victim actual perceived ethnicity nation race religion sexual orientation penalty murder raised year crime life imprisonment hate crime penalty viole...
#
# ---
#
# Heading: Georgia
# Content: general provision georgian law racist motivation considered aggravating circumstance prosecution ordinary offense certain crime involving racist motivation however defined specific offense georgian cr...
#
# ---
#
# Heading: Germany
# Content: german criminal code hate crime legislation instead criminalizes hate speech number different law including volksverhetzung german legal framework motivation taken account identifying element offence ...
#
# ---
#
# Heading: Greece
# Content: article law section penalises incitement discrimination hatred violence towards individual group racial national religious origin public written oral expression section prohibits establishment members...
#
# ---
#
# Heading: Hungary
# Content: violent action cruelty coercion threat made basis victim actual perceived national ethnic religious status membership particular social group punishable article hungarian criminal code article added c...
#
# ---
#
# Heading: Iceland
# Content: section icelandic penal code state anyone ridiculing slanderous insulting threatening manner publicly abuse person group people basis nationality skin colour race religion sexual orientation shall fin...
#
# ---
#
# Heading: India
# Content: india specific law governing hate crime general hate speech covered indian penal code...
#
# ---
#
# Heading: Ireland
# Content: prohibition incitement hatred act created offence inciting hatred group person account race colour nationality religion ethnic national origin membership traveller community indigenous minority group ...
#
# ---
#
# Heading: Italy
# Content: italian criminal law section law legge mancino mancino law contains provision crime motivated racial ethnic national religious bias italy party convention cybercrime additional protocol...
#
# ---
#
# Heading: Kazakhstan
# Content: kazakhstan constitutional provision prohibiting propaganda promoting racial ethnic superiority...
#
# ---
#
# Heading: Kyrgyzstan
# Content: kyrgyzstan constitution state party prohibits kind discrimination ground origin sex race nationality language faith political religious conviction personal social trait circumstance prohibition racial...
#
# ---
#
# Heading: Poland
# Content: article constitution poland prohibits organization whose programme activity sanction racial national hatred...
#
# ---
#
# Heading: Russia
